# %% [markdown]
# # Illuminating Cognizance: A Comprehensive Look Into Major Power Outages in the U.S.
#
# **Name(s)**: Phu Dang
#
# **Website Link**: (your website link)

# %% [markdown]
# ## Code

# %%
# Importing packages and libraries

import pandas as pd
import numpy as np
import os

import plotly.express as px
pd.options.plotting.backend = 'plotly'

# %%
# Adjust dataframe display options to view full output
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
# pd.set_option('display.max_rows', None)

# Reset to default, comment-out 2 (or 3) lines above and 
    # uncomment 2 lines below, run all before pushing to GitHub
    # Reset to default helps limit the display scope of output dataframes, 
    # easier to navigate notebook
# pd.set_option('display.max_columns', 20)
# pd.set_option('display.width', 80)

# %% [markdown]
# ## Introduction
#
# Analysis questions of interest:
# 1. Are there any possible connections between outage duration and regional consumption information?
#     - Look into different types of information: price vs. consumption vs. customers served
#     - <b>(Personal favorite)</b> I plan to investigate this thoroughly
#     <br></br>
# 2. Is there a relation between anomaly level and cause category?
#
# 3. Do the start times of outages seem to affect outage duration?
#     - Rationale: A sudden outage at night can give workers more time and space to fix overnight
#
# 4. What are some common characteristics of longer outages?
#
# ### Cleaning and EDA

# %%
# Importing dataset

path = os.path.join('data', 'outage.csv').replace('\\', '/')

df = pd.read_csv(path, header=5, skiprows=[6])
df = df.loc[:, ~df.columns.isin(['OBS', 'variables'])]
df.head()
# Out:
#    YEAR  MONTH U.S._STATE POSTAL.CODE NERC.REGION      CLIMATE.REGION  \
# 0  2011    7.0  Minnesota          MN         MRO  East North Central
# 1  2014    5.0  Minnesota          MN         MRO  East North Central
# 2  2010   10.0  Minnesota          MN         MRO  East North Central
# 3  2012    6.0  Minnesota          MN         MRO  East North Central
# 4  2015    7.0  Minnesota          MN         MRO  East North Central
#
#    ANOMALY.LEVEL CLIMATE.CATEGORY          OUTAGE.START.DATE  \
# 0           -0.3           normal       Friday, July 1, 2011
# 1           -0.1           normal       Sunday, May 11, 2014
# 2           -1.5             cold  Tuesday, October 26, 2010
# 3           -0.1           normal     Tuesday, June 19, 2012
# 4            1.2             warm    Saturday, July 18, 2015
#
#   OUTAGE.START.TIME     OUTAGE.RESTORATION.DATE OUTAGE.RESTORATION.TIME  \
# 0        5:00:00 PM        Sunday, July 3, 2011              8:00:00 PM
# 1        6:38:00 PM        Sunday, May 11, 2014              6:39:00 PM
# 2        8:00:00 PM  Thursday, October 28, 2010             10:00:00 PM
# 3        4:30:00 AM    Wednesday, June 20, 2012             11:00:00 PM
# 4        2:00:00 AM       Sunday, July 19, 2015              7:00:00 AM
#
#        CAUSE.CATEGORY CAUSE.CATEGORY.DETAIL HURRICANE.NAMES  OUTAGE.DURATION  \
# 0      severe weather                   NaN             NaN           3060.0
# 1  intentional attack             vandalism             NaN              1.0
# 2      severe weather            heavy wind             NaN           3000.0
# 3      severe weather          thunderstorm             NaN           2550.0
# 4      severe weather                   NaN             NaN           1740.0
#
#    DEMAND.LOSS.MW  CUSTOMERS.AFFECTED  RES.PRICE  COM.PRICE  IND.PRICE  \
# 0             NaN             70000.0      11.60       9.18       6.81
# 1             NaN                 NaN      12.12       9.71       6.49
# 2             NaN             70000.0      10.87       8.19       6.07
# 3             NaN             68200.0      11.79       9.25       6.71
# 4           250.0            250000.0      13.07      10.16       7.74
#
#    TOTAL.PRICE  RES.SALES  COM.SALES  IND.SALES  TOTAL.SALES  RES.PERCEN  \
# 0         9.28  2332915.0  2114774.0  2113291.0    6562520.0   35.549073
# 1         9.28  1586986.0  1807756.0  1887927.0    5284231.0   30.032487
# 2         8.15  1467293.0  1801683.0  1951295.0    5222116.0   28.097672
# 3         9.19  1851519.0  1941174.0  1993026.0    5787064.0   31.994099
# 4        10.43  2028875.0  2161612.0  1777937.0    5970339.0   33.982576
#
#    COM.PERCEN  IND.PERCEN  RES.CUSTOMERS  COM.CUSTOMERS  IND.CUSTOMERS  \
# 0   32.225029   32.202431        2308736         276286          10673
# 1   34.210389   35.727564        2345860         284978           9898
# 2   34.501015   37.365983        2300291         276463          10150
# 3   33.543330   34.439329        2317336         278466          11010
# 4   36.205850   29.779498        2374674         289044           9812
#
#    TOTAL.CUSTOMERS  RES.CUST.PCT  COM.CUST.PCT  IND.CUST.PCT  \
# 0          2595696       88.9448       10.6440        0.4112
# 1          2640737       88.8335       10.7916        0.3748
# 2          2586905       88.9206       10.6870        0.3924
# 3          2606813       88.8954       10.6822        0.4224
# 4          2673531       88.8216       10.8113        0.3670
#
#    PC.REALGSP.STATE  PC.REALGSP.USA  PC.REALGSP.REL  PC.REALGSP.CHANGE  \
# 0             51268           47586        1.077376                1.6
# 1             53499           49091        1.089792                1.9
# 2             50447           47287        1.066826                2.7
# 3             51598           48156        1.071476                0.6
# 4             54431           49844        1.092027                1.7
#
#    UTIL.REALGSP  TOTAL.REALGSP  UTIL.CONTRI  PI.UTIL.OFUSA  POPULATION  \
# 0          4802         274182     1.751391            2.2     5348119
# 1          5226         291955     1.790002            2.2     5457125
# 2          4571         267895     1.706266            2.1     5310903
# 3          5364         277627     1.932089            2.2     5380443
# 4          4873         292023     1.668704            2.2     5489594
#
#    POPPCT_URBAN  POPPCT_UC  POPDEN_URBAN  POPDEN_UC  POPDEN_RURAL  \
# 0         73.27      15.28        2279.0     1700.5          18.2
# 1         73.27      15.28        2279.0     1700.5          18.2
# 2         73.27      15.28        2279.0     1700.5          18.2
# 3         73.27      15.28        2279.0     1700.5          18.2
# 4         73.27      15.28        2279.0     1700.5          18.2
#
#    AREAPCT_URBAN  AREAPCT_UC   PCT_LAND  PCT_WATER_TOT  PCT_WATER_INLAND
# 0           2.14         0.6  91.592666       8.407334          5.478743
# 1           2.14         0.6  91.592666       8.407334          5.478743
# 2           2.14         0.6  91.592666       8.407334          5.478743
# 3           2.14         0.6  91.592666       8.407334          5.478743
# 4           2.14         0.6  91.592666       8.407334          5.478743

# %%
df.columns
# Out:
# Index(['YEAR', 'MONTH', 'U.S._STATE', 'POSTAL.CODE', 'NERC.REGION',
#        'CLIMATE.REGION', 'ANOMALY.LEVEL', 'CLIMATE.CATEGORY',
#        'OUTAGE.START.DATE', 'OUTAGE.START.TIME', 'OUTAGE.RESTORATION.DATE',
#        'OUTAGE.RESTORATION.TIME', 'CAUSE.CATEGORY', 'CAUSE.CATEGORY.DETAIL',
#        'HURRICANE.NAMES', 'OUTAGE.DURATION', 'DEMAND.LOSS.MW',
#        'CUSTOMERS.AFFECTED', 'RES.PRICE', 'COM.PRICE', 'IND.PRICE',
#        'TOTAL.PRICE', 'RES.SALES', 'COM.SALES', 'IND.SALES', 'TOTAL.SALES',
#        'RES.PERCEN', 'COM.PERCEN', 'IND.PERCEN', 'RES.CUSTOMERS',
#        'COM.CUSTOMERS', 'IND.CUSTOMERS', 'TOTAL.CUSTOMERS', 'RES.CUST.PCT',
#        'COM.CUST.PCT', 'IND.CUST.PCT', 'PC.REALGSP.STATE', 'PC.REALGSP.USA',
#        'PC.REALGSP.REL', 'PC.REALGSP.CHANGE', 'UTIL.REALGSP', 'TOTAL.REALGSP',
#        'UTIL.CONTRI', 'PI.UTIL.OFUSA', 'POPULATION', 'POPPCT_URBAN',
#        'POPPCT_UC', 'POPDEN_URBAN', 'POPDEN_UC', 'POPDEN_RURAL',
#        'AREAPCT_URBAN', 'AREAPCT_UC', 'PCT_LAND', 'PCT_WATER_TOT',
#        'PCT_WATER_INLAND'],
#       dtype='object')

# %%
# Change postal code column name to STATE.ABBR (state abbreviation)

df.rename(columns={'POSTAL.CODE': 'STATE.ABBR'}, inplace=True)

# %%
df.head()
# Out:
#    YEAR  MONTH U.S._STATE STATE.ABBR NERC.REGION      CLIMATE.REGION  \
# 0  2011    7.0  Minnesota         MN         MRO  East North Central
# 1  2014    5.0  Minnesota         MN         MRO  East North Central
# 2  2010   10.0  Minnesota         MN         MRO  East North Central
# 3  2012    6.0  Minnesota         MN         MRO  East North Central
# 4  2015    7.0  Minnesota         MN         MRO  East North Central
#
#    ANOMALY.LEVEL CLIMATE.CATEGORY          OUTAGE.START.DATE  \
# 0           -0.3           normal       Friday, July 1, 2011
# 1           -0.1           normal       Sunday, May 11, 2014
# 2           -1.5             cold  Tuesday, October 26, 2010
# 3           -0.1           normal     Tuesday, June 19, 2012
# 4            1.2             warm    Saturday, July 18, 2015
#
#   OUTAGE.START.TIME     OUTAGE.RESTORATION.DATE OUTAGE.RESTORATION.TIME  \
# 0        5:00:00 PM        Sunday, July 3, 2011              8:00:00 PM
# 1        6:38:00 PM        Sunday, May 11, 2014              6:39:00 PM
# 2        8:00:00 PM  Thursday, October 28, 2010             10:00:00 PM
# 3        4:30:00 AM    Wednesday, June 20, 2012             11:00:00 PM
# 4        2:00:00 AM       Sunday, July 19, 2015              7:00:00 AM
#
#        CAUSE.CATEGORY CAUSE.CATEGORY.DETAIL HURRICANE.NAMES  OUTAGE.DURATION  \
# 0      severe weather                   NaN             NaN           3060.0
# 1  intentional attack             vandalism             NaN              1.0
# 2      severe weather            heavy wind             NaN           3000.0
# 3      severe weather          thunderstorm             NaN           2550.0
# 4      severe weather                   NaN             NaN           1740.0
#
#    DEMAND.LOSS.MW  CUSTOMERS.AFFECTED  RES.PRICE  COM.PRICE  IND.PRICE  \
# 0             NaN             70000.0      11.60       9.18       6.81
# 1             NaN                 NaN      12.12       9.71       6.49
# 2             NaN             70000.0      10.87       8.19       6.07
# 3             NaN             68200.0      11.79       9.25       6.71
# 4           250.0            250000.0      13.07      10.16       7.74
#
#    TOTAL.PRICE  RES.SALES  COM.SALES  IND.SALES  TOTAL.SALES  RES.PERCEN  \
# 0         9.28  2332915.0  2114774.0  2113291.0    6562520.0   35.549073
# 1         9.28  1586986.0  1807756.0  1887927.0    5284231.0   30.032487
# 2         8.15  1467293.0  1801683.0  1951295.0    5222116.0   28.097672
# 3         9.19  1851519.0  1941174.0  1993026.0    5787064.0   31.994099
# 4        10.43  2028875.0  2161612.0  1777937.0    5970339.0   33.982576
#
#    COM.PERCEN  IND.PERCEN  RES.CUSTOMERS  COM.CUSTOMERS  IND.CUSTOMERS  \
# 0   32.225029   32.202431        2308736         276286          10673
# 1   34.210389   35.727564        2345860         284978           9898
# 2   34.501015   37.365983        2300291         276463          10150
# 3   33.543330   34.439329        2317336         278466          11010
# 4   36.205850   29.779498        2374674         289044           9812
#
#    TOTAL.CUSTOMERS  RES.CUST.PCT  COM.CUST.PCT  IND.CUST.PCT  \
# 0          2595696       88.9448       10.6440        0.4112
# 1          2640737       88.8335       10.7916        0.3748
# 2          2586905       88.9206       10.6870        0.3924
# 3          2606813       88.8954       10.6822        0.4224
# 4          2673531       88.8216       10.8113        0.3670
#
#    PC.REALGSP.STATE  PC.REALGSP.USA  PC.REALGSP.REL  PC.REALGSP.CHANGE  \
# 0             51268           47586        1.077376                1.6
# 1             53499           49091        1.089792                1.9
# 2             50447           47287        1.066826                2.7
# 3             51598           48156        1.071476                0.6
# 4             54431           49844        1.092027                1.7
#
#    UTIL.REALGSP  TOTAL.REALGSP  UTIL.CONTRI  PI.UTIL.OFUSA  POPULATION  \
# 0          4802         274182     1.751391            2.2     5348119
# 1          5226         291955     1.790002            2.2     5457125
# 2          4571         267895     1.706266            2.1     5310903
# 3          5364         277627     1.932089            2.2     5380443
# 4          4873         292023     1.668704            2.2     5489594
#
#    POPPCT_URBAN  POPPCT_UC  POPDEN_URBAN  POPDEN_UC  POPDEN_RURAL  \
# 0         73.27      15.28        2279.0     1700.5          18.2
# 1         73.27      15.28        2279.0     1700.5          18.2
# 2         73.27      15.28        2279.0     1700.5          18.2
# 3         73.27      15.28        2279.0     1700.5          18.2
# 4         73.27      15.28        2279.0     1700.5          18.2
#
#    AREAPCT_URBAN  AREAPCT_UC   PCT_LAND  PCT_WATER_TOT  PCT_WATER_INLAND
# 0           2.14         0.6  91.592666       8.407334          5.478743
# 1           2.14         0.6  91.592666       8.407334          5.478743
# 2           2.14         0.6  91.592666       8.407334          5.478743
# 3           2.14         0.6  91.592666       8.407334          5.478743
# 4           2.14         0.6  91.592666       8.407334          5.478743

# %%
df.dtypes
# Out:
# YEAR                         int64
# MONTH                      float64
# U.S._STATE                  object
# STATE.ABBR                  object
# NERC.REGION                 object
# CLIMATE.REGION              object
# ANOMALY.LEVEL              float64
# CLIMATE.CATEGORY            object
# OUTAGE.START.DATE           object
# OUTAGE.START.TIME           object
# OUTAGE.RESTORATION.DATE     object
# OUTAGE.RESTORATION.TIME     object
# CAUSE.CATEGORY              object
# CAUSE.CATEGORY.DETAIL       object
# HURRICANE.NAMES             object
# OUTAGE.DURATION            float64
# DEMAND.LOSS.MW             float64
# CUSTOMERS.AFFECTED         float64
# RES.PRICE                  float64
# COM.PRICE                  float64
# IND.PRICE                  float64
# TOTAL.PRICE                float64
# RES.SALES                  float64
# COM.SALES                  float64
# IND.SALES                  float64
# TOTAL.SALES                float64
# RES.PERCEN                 float64
# COM.PERCEN                 float64
# IND.PERCEN                 float64
# RES.CUSTOMERS                int64
# COM.CUSTOMERS                int64
# IND.CUSTOMERS                int64
# TOTAL.CUSTOMERS              int64
# RES.CUST.PCT               float64
# COM.CUST.PCT               float64
# IND.CUST.PCT               float64
# PC.REALGSP.STATE             int64
# PC.REALGSP.USA               int64
# PC.REALGSP.REL             float64
# PC.REALGSP.CHANGE          float64
# UTIL.REALGSP                 int64
# TOTAL.REALGSP                int64
# UTIL.CONTRI                float64
# PI.UTIL.OFUSA              float64
# POPULATION                   int64
# POPPCT_URBAN               float64
# POPPCT_UC                  float64
# POPDEN_URBAN               float64
# POPDEN_UC                  float64
# POPDEN_RURAL               float64
# AREAPCT_URBAN              float64
# AREAPCT_UC                 float64
# PCT_LAND                   float64
# PCT_WATER_TOT              float64
# PCT_WATER_INLAND           float64
# dtype: object

# %%
# Combining OUTAGE.START.DATE and OUTAGE.START.TIME

dates_start = df['OUTAGE.START.DATE'] + ' ' + df['OUTAGE.START.TIME']
df['OUTAGE.START'] = pd.to_datetime(dates_start)

dates_end = df['OUTAGE.RESTORATION.DATE'] + ' ' + df['OUTAGE.RESTORATION.TIME']
df['OUTAGE.END'] = pd.to_datetime(dates_end)

df.drop(columns=['OUTAGE.START.DATE', 'OUTAGE.START.TIME', \
    'OUTAGE.RESTORATION.DATE', 'OUTAGE.RESTORATION.TIME'], inplace=True)

# %%
# Get counts of missing values in each column

df.isna().sum()
# Out:
# YEAR                        0
# MONTH                       9
# U.S._STATE                  0
# STATE.ABBR                  0
# NERC.REGION                 0
# CLIMATE.REGION              6
# ANOMALY.LEVEL               9
# CLIMATE.CATEGORY            9
# CAUSE.CATEGORY              0
# CAUSE.CATEGORY.DETAIL     471
# HURRICANE.NAMES          1462
# OUTAGE.DURATION            58
# DEMAND.LOSS.MW            705
# CUSTOMERS.AFFECTED        443
# RES.PRICE                  22
# COM.PRICE                  22
# IND.PRICE                  22
# TOTAL.PRICE                22
# RES.SALES                  22
# COM.SALES                  22
# IND.SALES                  22
# TOTAL.SALES                22
# RES.PERCEN                 22
# COM.PERCEN                 22
# IND.PERCEN                 22
# RES.CUSTOMERS               0
# COM.CUSTOMERS               0
# IND.CUSTOMERS               0
# TOTAL.CUSTOMERS             0
# RES.CUST.PCT                0
# COM.CUST.PCT                0
# IND.CUST.PCT                0
# PC.REALGSP.STATE            0
# PC.REALGSP.USA              0
# PC.REALGSP.REL              0
# PC.REALGSP.CHANGE           0
# UTIL.REALGSP                0
# TOTAL.REALGSP               0
# UTIL.CONTRI                 0
# PI.UTIL.OFUSA               0
# POPULATION                  0
# POPPCT_URBAN                0
# POPPCT_UC                   0
# POPDEN_URBAN                0
# POPDEN_UC                  10
# POPDEN_RURAL               10
# AREAPCT_URBAN               0
# AREAPCT_UC                  0
# PCT_LAND                    0
# PCT_WATER_TOT               0
# PCT_WATER_INLAND            0
# OUTAGE.START                9
# OUTAGE.END                 58
# dtype: int64

# %%
df.dtypes
# Out:
# YEAR                              int64
# MONTH                           float64
# U.S._STATE                       object
# STATE.ABBR                       object
# NERC.REGION                      object
# CLIMATE.REGION                   object
# ANOMALY.LEVEL                   float64
# CLIMATE.CATEGORY                 object
# CAUSE.CATEGORY                   object
# CAUSE.CATEGORY.DETAIL            object
# HURRICANE.NAMES                  object
# OUTAGE.DURATION                 float64
# DEMAND.LOSS.MW                  float64
# CUSTOMERS.AFFECTED              float64
# RES.PRICE                       float64
# COM.PRICE                       float64
# IND.PRICE                       float64
# TOTAL.PRICE                     float64
# RES.SALES                       float64
# COM.SALES                       float64
# IND.SALES                       float64
# TOTAL.SALES                     float64
# RES.PERCEN                      float64
# COM.PERCEN                      float64
# IND.PERCEN                      float64
# RES.CUSTOMERS                     int64
# COM.CUSTOMERS                     int64
# IND.CUSTOMERS                     int64
# TOTAL.CUSTOMERS                   int64
# RES.CUST.PCT                    float64
# COM.CUST.PCT                    float64
# IND.CUST.PCT                    float64
# PC.REALGSP.STATE                  int64
# PC.REALGSP.USA                    int64
# PC.REALGSP.REL                  float64
# PC.REALGSP.CHANGE               float64
# UTIL.REALGSP                      int64
# TOTAL.REALGSP                     int64
# UTIL.CONTRI                     float64
# PI.UTIL.OFUSA                   float64
# POPULATION                        int64
# POPPCT_URBAN                    float64
# POPPCT_UC                       float64
# POPDEN_URBAN                    float64
# POPDEN_UC                       float64
# POPDEN_RURAL                    float64
# AREAPCT_URBAN                   float64
# AREAPCT_UC                      float64
# PCT_LAND                        float64
# PCT_WATER_TOT                   float64
# PCT_WATER_INLAND                float64
# OUTAGE.START             datetime64[ns]
# OUTAGE.END               datetime64[ns]
# dtype: object

# %%
# Adding a duration column in hours

df['DURATION.HR'] = df['OUTAGE.DURATION'] / 60

# %%
# Check min and max duration 
print(df['DURATION.HR'].min())
print(df['DURATION.HR'].max())
# Out:
# 0.0
# 1810.8833333333334

# %%
df.head()
# Out:
#    YEAR  MONTH U.S._STATE STATE.ABBR NERC.REGION      CLIMATE.REGION  \
# 0  2011    7.0  Minnesota         MN         MRO  East North Central
# 1  2014    5.0  Minnesota         MN         MRO  East North Central
# 2  2010   10.0  Minnesota         MN         MRO  East North Central
# 3  2012    6.0  Minnesota         MN         MRO  East North Central
# 4  2015    7.0  Minnesota         MN         MRO  East North Central
#
#    ANOMALY.LEVEL CLIMATE.CATEGORY      CAUSE.CATEGORY CAUSE.CATEGORY.DETAIL  \
# 0           -0.3           normal      severe weather                   NaN
# 1           -0.1           normal  intentional attack             vandalism
# 2           -1.5             cold      severe weather            heavy wind
# 3           -0.1           normal      severe weather          thunderstorm
# 4            1.2             warm      severe weather                   NaN
#
#   HURRICANE.NAMES  OUTAGE.DURATION  DEMAND.LOSS.MW  CUSTOMERS.AFFECTED  \
# 0             NaN           3060.0             NaN             70000.0
# 1             NaN              1.0             NaN                 NaN
# 2             NaN           3000.0             NaN             70000.0
# 3             NaN           2550.0             NaN             68200.0
# 4             NaN           1740.0           250.0            250000.0
#
#    RES.PRICE  COM.PRICE  IND.PRICE  TOTAL.PRICE  RES.SALES  COM.SALES  \
# 0      11.60       9.18       6.81         9.28  2332915.0  2114774.0
# 1      12.12       9.71       6.49         9.28  1586986.0  1807756.0
# 2      10.87       8.19       6.07         8.15  1467293.0  1801683.0
# 3      11.79       9.25       6.71         9.19  1851519.0  1941174.0
# 4      13.07      10.16       7.74        10.43  2028875.0  2161612.0
#
#    IND.SALES  TOTAL.SALES  RES.PERCEN  COM.PERCEN  IND.PERCEN  RES.CUSTOMERS  \
# 0  2113291.0    6562520.0   35.549073   32.225029   32.202431        2308736
# 1  1887927.0    5284231.0   30.032487   34.210389   35.727564        2345860
# 2  1951295.0    5222116.0   28.097672   34.501015   37.365983        2300291
# 3  1993026.0    5787064.0   31.994099   33.543330   34.439329        2317336
# 4  1777937.0    5970339.0   33.982576   36.205850   29.779498        2374674
#
#    COM.CUSTOMERS  IND.CUSTOMERS  TOTAL.CUSTOMERS  RES.CUST.PCT  COM.CUST.PCT  \
# 0         276286          10673          2595696       88.9448       10.6440
# 1         284978           9898          2640737       88.8335       10.7916
# 2         276463          10150          2586905       88.9206       10.6870
# 3         278466          11010          2606813       88.8954       10.6822
# 4         289044           9812          2673531       88.8216       10.8113
#
#    IND.CUST.PCT  PC.REALGSP.STATE  PC.REALGSP.USA  PC.REALGSP.REL  \
# 0        0.4112             51268           47586        1.077376
# 1        0.3748             53499           49091        1.089792
# 2        0.3924             50447           47287        1.066826
# 3        0.4224             51598           48156        1.071476
# 4        0.3670             54431           49844        1.092027
#
#    PC.REALGSP.CHANGE  UTIL.REALGSP  TOTAL.REALGSP  UTIL.CONTRI  PI.UTIL.OFUSA  \
# 0                1.6          4802         274182     1.751391            2.2
# 1                1.9          5226         291955     1.790002            2.2
# 2                2.7          4571         267895     1.706266            2.1
# 3                0.6          5364         277627     1.932089            2.2
# 4                1.7          4873         292023     1.668704            2.2
#
#    POPULATION  POPPCT_URBAN  POPPCT_UC  POPDEN_URBAN  POPDEN_UC  POPDEN_RURAL  \
# 0     5348119         73.27      15.28        2279.0     1700.5          18.2
# 1     5457125         73.27      15.28        2279.0     1700.5          18.2
# 2     5310903         73.27      15.28        2279.0     1700.5          18.2
# 3     5380443         73.27      15.28        2279.0     1700.5          18.2
# 4     5489594         73.27      15.28        2279.0     1700.5          18.2
#
#    AREAPCT_URBAN  AREAPCT_UC   PCT_LAND  PCT_WATER_TOT  PCT_WATER_INLAND  \
# 0           2.14         0.6  91.592666       8.407334          5.478743
# 1           2.14         0.6  91.592666       8.407334          5.478743
# 2           2.14         0.6  91.592666       8.407334          5.478743
# 3           2.14         0.6  91.592666       8.407334          5.478743
# 4           2.14         0.6  91.592666       8.407334          5.478743
#
#          OUTAGE.START          OUTAGE.END  DURATION.HR
# 0 2011-07-01 17:00:00 2011-07-03 20:00:00    51.000000
# 1 2014-05-11 18:38:00 2014-05-11 18:39:00     0.016667
# 2 2010-10-26 20:00:00 2010-10-28 22:00:00    50.000000
# 3 2012-06-19 04:30:00 2012-06-20 23:00:00    42.500000
# 4 2015-07-18 02:00:00 2015-07-19 07:00:00    29.000000

# %% [markdown]
# ### Univariate Analysis

# %%
# Plotting the distribution of outage durations

fig1 = px.histogram(df, x='DURATION.HR', nbins=200, histnorm='probability', \
    title='Distribution of outage duration, in hours')
fig1.update_layout(xaxis_range=[0, 360])
fig1.update_xaxes(title_text='duration in hours')
fig1

# %%
# Write to html file

path = os.path.join('assets', 'uni_1.html')
fig1.write_html(path, include_plotlyjs='cdn')

# %%
# Sanity check

573 / len(df['DURATION.HR'])
# Out:
# 0.37353324641460234

# %%
# Plotting the distribution of cause category

fig2 = px.histogram(df, x='CAUSE.CATEGORY', histnorm='probability', \
    title='Distribution of outage cause category')
fig2.update_xaxes(title_text='cause category')
fig2

# %%
# Write to html file

path = os.path.join('assets', 'uni_2.html')
fig2.write_html(path, include_plotlyjs='cdn')

# %% [markdown]
# ### Bivariate Analysis

# %%
# Plotting a scatterplot between outage duration and residential electricity price

fig3 = px.scatter(df, x='RES.PRICE', y='DURATION.HR', title='Outage duration and residential electricity price, monthly')
fig3.update_xaxes(title_text='cents/kilowatt-hour')
fig3.update_yaxes(title_text='hours')
fig3

# %%
# Write to html file

path = os.path.join('assets', 'bi_1.html')
fig3.write_html(path, include_plotlyjs='cdn')

# %%
# Plotting a scatterplot between outage duration and customers served

fig4 = px.scatter(df, x='TOTAL.CUSTOMERS', y='DURATION.HR'\
    , title='Outage duration and total number of customers served, annually')
fig4.update_xaxes(title_text='number of customers served')
fig4.update_yaxes(title_text='hours')
fig4

# %%
# Plotting a barplot between outage duration and regional economic output

fig5 = px.scatter(df, x='PC.REALGSP.STATE', y='DURATION.HR'\
    , title='Outage duration and per capita GSP')
fig5.update_xaxes(title_text='per capita real gross state product (measured in 2009 chained U.S. dollars)')
fig5.update_yaxes(title_text='hours')
fig5

# %%
# Write to html file

path = os.path.join('assets', 'bi_2.html')
fig5.write_html(path, include_plotlyjs='cdn')

# %% [markdown]
# ### Interesting Aggregates

# %%
# Plot average outage duration for every combination of state and cause category

group1 = pd.pivot_table(df, index=['U.S._STATE'], columns=['CAUSE.CATEGORY'], \
    values='DURATION.HR', aggfunc=np.mean)
group1['dummy'] = group1.sum(axis=1)
group1 = group1.sort_values(by='dummy', ascending=True).drop(columns=['dummy'])
fig6 = group1.plot(kind='barh', \
    title='Average outage duration by state and cause category',
    labels={'U.S._STATE': 'state', 'value': 'average outage duration hours'})
fig6.update_layout(height=1000, width=1500, legend=dict(title='cause category'))
fig6

# %%
# Write to html file

path = os.path.join('assets', 'multi_1.html')
fig6.write_html(path, include_plotlyjs='cdn')

# %%
# Sanity check

group1.sum(axis=1).sort_values(ascending=False).index
# Out:
# Index(['Michigan', 'Louisiana', 'Wisconsin', 'New York', 'Arizona', 'Indiana',
#        'Texas', 'Kentucky', 'California', 'Florida', 'Kansas', 'West Virginia',
#        'Iowa', 'Washington', 'New Jersey', 'Pennsylvania', 'Ohio', 'Illinois',
#        'Oklahoma', 'Missouri', 'District of Columbia', 'Massachusetts',
#        'Tennessee', 'Maryland', 'Arkansas', 'Maine', 'Minnesota', 'Utah',
#        'Nebraska', 'South Carolina', 'Colorado', 'Oregon', 'North Carolina',
#        'Connecticut', 'Delaware', 'Virginia', 'Idaho', 'New Hampshire',
#        'Georgia', 'Alabama', 'Hawaii', 'North Dakota', 'Nevada', 'Mississippi',
#        'New Mexico', 'Wyoming', 'Montana', 'South Dakota', 'Vermont'],
#       dtype='object', name='U.S._STATE')

# %%
# Get aggregated mean outage duration in minutes, hours, and customers affected by state and cause category

pd.set_option('display.max_rows', None)
group2 = df.groupby(by=['STATE.ABBR', 'CAUSE.CATEGORY']).mean()[['OUTAGE.DURATION', 'DURATION.HR', 'CUSTOMERS.AFFECTED']]
group2.rename(columns={'OUTAGE.DURATION': 'Avg duration (mins)', \
    'DURATION.HR': 'Avg duration (hrs)',
    'CUSTOMERS.AFFECTED': 'Avg # of customers affected'})
# pd.set_option('display.max_rows', 20)
# Out:
#                                           Avg duration (mins)  \
# STATE.ABBR CAUSE.CATEGORY
# AK         equipment failure                              NaN
# AL         intentional attack                       77.000000
#            severe weather                         1421.750000
# AR         equipment failure                       105.000000
#            intentional attack                      547.833333
#            islanding                                 3.000000
#            public appeal                          1063.714286
#            severe weather                         2701.800000
# AZ         equipment failure                       138.500000
#            intentional attack                      639.600000
#            severe weather                        25726.500000
#            system operability disruption           384.500000
# CA         equipment failure                       524.809524
#            fuel supply emergency                  6154.600000
#            intentional attack                      946.458333
#            islanding                               214.857143
#            public appeal                          2028.111111
#            severe weather                         2928.373134
#            system operability disruption           363.666667
# CO         fuel supply emergency                          NaN
#            intentional attack                      117.000000
#            islanding                                 2.000000
#            severe weather                         2727.250000
#            system operability disruption           279.750000
# CT         intentional attack                       49.125000
#            severe weather                         2262.600000
# DC         equipment failure                       159.000000
#            severe weather                         4764.111111
# DE         equipment failure                        50.000000
#            intentional attack                       38.918919
#            severe weather                         2153.500000
#            system operability disruption                  NaN
# FL         equipment failure                       554.500000
#            intentional attack                       50.000000
#            public appeal                          4320.000000
#            severe weather                         6420.192308
#            system operability disruption           205.700000
# GA         intentional attack                      108.000000
#            severe weather                         1422.750000
# HI         severe weather                          997.500000
#            system operability disruption           237.000000
# IA         intentional attack                     5657.800000
#            severe weather                         3353.666667
# ID         intentional attack                      307.500000
#            public appeal                          1548.000000
#            system operability disruption           179.666667
# IL         equipment failure                       149.000000
#            fuel supply emergency                  2761.000000
#            intentional attack                     1450.000000
#            public appeal                           120.000000
#            severe weather                         1650.700000
# IN         equipment failure                         1.000000
#            fuel supply emergency                 12240.000000
#            intentional attack                      421.875000
#            islanding                               125.333333
#            severe weather                         4523.291667
#            system operability disruption          4671.600000
# KS         intentional attack                      561.000000
#            public appeal                           913.000000
#            severe weather                         9346.000000
# KY         equipment failure                       652.000000
#            fuel supply emergency                 12570.000000
#            intentional attack                      108.000000
#            severe weather                         4480.111111
# LA         equipment failure                       176.333333
#            fuel supply emergency                 28170.000000
#            public appeal                          1359.214286
#            severe weather                         7186.928571
#            system operability disruption          1144.666667
# MA         fuel supply emergency                  2891.000000
#            intentional attack                      384.250000
#            severe weather                         1556.571429
#            system operability disruption            67.000000
# MD         intentional attack                      225.320000
#            severe weather                         4006.937500
#            system operability disruption           304.000000
# ME         fuel supply emergency                  1676.000000
#            intentional attack                       82.666667
#            islanding                               881.000000
#            severe weather                         1669.400000
# MI         equipment failure                     26435.333333
#            intentional attack                     3635.250000
#            islanding                                 1.000000
#            public appeal                          1078.000000
#            severe weather                         4831.650602
#            system operability disruption          2610.000000
# MN         intentional attack                      369.500000
#            severe weather                         3585.545455
# MO         intentional attack                      408.000000
#            severe weather                         4483.818182
#            system operability disruption            65.000000
# MS         intentional attack                       12.000000
#            system operability disruption           300.000000
# MT         intentional attack                       93.000000
#            islanding                                34.500000
# NC         intentional attack                     1063.750000
#            severe weather                         1738.933333
#            system operability disruption            82.200000
# ND         fuel supply emergency                          NaN
#            public appeal                           720.000000
# NE         public appeal                           159.000000
#            severe weather                         3221.333333
# NH         intentional attack                       60.000000
#            severe weather                         1597.500000
# NJ         intentional attack                       91.125000
#            severe weather                         6372.863636
#            system operability disruption           748.500000
# NM         fuel supply emergency                    76.000000
#            intentional attack                      174.500000
#            system operability disruption             0.000000
# NV         intentional attack                      553.285714
# NY         equipment failure                       247.000000
#            fuel supply emergency                 16687.250000
#            intentional attack                      309.083333
#            public appeal                          2655.000000
#            severe weather                         6034.575758
#            system operability disruption          1176.571429
# OH         equipment failure                              NaN
#            intentional attack                      327.285714
#            severe weather                         4322.269231
#            system operability disruption          1744.500000
# OK         intentional attack                       75.666667
#            islanding                               984.000000
#            public appeal                           704.000000
#            severe weather                         4206.466667
# OR         equipment failure                       200.000000
#            intentional attack                      394.105263
#            severe weather                         2295.800000
# PA         equipment failure                       376.000000
#            intentional attack                     1526.833333
#            severe weather                         4314.000000
#            system operability disruption           329.000000
# SC         severe weather                         3135.000000
# SD         islanding                               120.000000
# TN         equipment failure                       404.000000
#            intentional attack                      171.000000
#            public appeal                          2700.000000
#            severe weather                         1386.350000
#            system operability disruption            20.000000
# TX         equipment failure                       405.600000
#            fuel supply emergency                 13920.000000
#            intentional attack                      298.769231
#            public appeal                          1140.411765
#            severe weather                         3854.890625
#            system operability disruption           810.800000
# UT         equipment failure                        15.000000
#            intentional attack                      142.285714
#            public appeal                          2275.000000
#            severe weather                          957.000000
#            system operability disruption           537.500000
# VA         equipment failure                              NaN
#            intentional attack                        2.000000
#            public appeal                           683.500000
#            severe weather                         1132.281250
#            system operability disruption           241.000000
# VT         intentional attack                       35.444444
# WA         equipment failure                      1204.000000
#            fuel supply emergency                     1.000000
#            intentional attack                      371.870968
#            islanding                                73.333333
#            public appeal                           248.000000
#            severe weather                         5473.550000
#            system operability disruption            25.000000
# WI         fuel supply emergency                 33971.250000
#            intentional attack                      459.000000
#            public appeal                           388.000000
#            severe weather                         1527.428571
# WV         intentional attack                        1.000000
#            severe weather                         9305.000000
# WY         equipment failure                        61.000000
#            intentional attack                        0.333333
#            islanding                                32.000000
#            severe weather                          106.000000
#
#                                           Avg duration (hrs)  \
# STATE.ABBR CAUSE.CATEGORY
# AK         equipment failure                             NaN
# AL         intentional attack                       1.283333
#            severe weather                          23.695833
# AR         equipment failure                        1.750000
#            intentional attack                       9.130556
#            islanding                                0.050000
#            public appeal                           17.728571
#            severe weather                          45.030000
# AZ         equipment failure                        2.308333
#            intentional attack                      10.660000
#            severe weather                         428.775000
#            system operability disruption            6.408333
# CA         equipment failure                        8.746825
#            fuel supply emergency                  102.576667
#            intentional attack                      15.774306
#            islanding                                3.580952
#            public appeal                           33.801852
#            severe weather                          48.806219
#            system operability disruption            6.061111
# CO         fuel supply emergency                         NaN
#            intentional attack                       1.950000
#            islanding                                0.033333
#            severe weather                          45.454167
#            system operability disruption            4.662500
# CT         intentional attack                       0.818750
#            severe weather                          37.710000
# DC         equipment failure                        2.650000
#            severe weather                          79.401852
# DE         equipment failure                        0.833333
#            intentional attack                       0.648649
#            severe weather                          35.891667
#            system operability disruption                 NaN
# FL         equipment failure                        9.241667
#            intentional attack                       0.833333
#            public appeal                           72.000000
#            severe weather                         107.003205
#            system operability disruption            3.428333
# GA         intentional attack                       1.800000
#            severe weather                          23.712500
# HI         severe weather                          16.625000
#            system operability disruption            3.950000
# IA         intentional attack                      94.296667
#            severe weather                          55.894444
# ID         intentional attack                       5.125000
#            public appeal                           25.800000
#            system operability disruption            2.994444
# IL         equipment failure                        2.483333
#            fuel supply emergency                   46.016667
#            intentional attack                      24.166667
#            public appeal                            2.000000
#            severe weather                          27.511667
# IN         equipment failure                        0.016667
#            fuel supply emergency                  204.000000
#            intentional attack                       7.031250
#            islanding                                2.088889
#            severe weather                          75.388194
#            system operability disruption           77.860000
# KS         intentional attack                       9.350000
#            public appeal                           15.216667
#            severe weather                         155.766667
# KY         equipment failure                       10.866667
#            fuel supply emergency                  209.500000
#            intentional attack                       1.800000
#            severe weather                          74.668519
# LA         equipment failure                        2.938889
#            fuel supply emergency                  469.500000
#            public appeal                           22.653571
#            severe weather                         119.782143
#            system operability disruption           19.077778
# MA         fuel supply emergency                   48.183333
#            intentional attack                       6.404167
#            severe weather                          25.942857
#            system operability disruption            1.116667
# MD         intentional attack                       3.755333
#            severe weather                          66.782292
#            system operability disruption            5.066667
# ME         fuel supply emergency                   27.933333
#            intentional attack                       1.377778
#            islanding                               14.683333
#            severe weather                          27.823333
# MI         equipment failure                      440.588889
#            intentional attack                      60.587500
#            islanding                                0.016667
#            public appeal                           17.966667
#            severe weather                          80.527510
#            system operability disruption           43.500000
# MN         intentional attack                       6.158333
#            severe weather                          59.759091
# MO         intentional attack                       6.800000
#            severe weather                          74.730303
#            system operability disruption            1.083333
# MS         intentional attack                       0.200000
#            system operability disruption            5.000000
# MT         intentional attack                       1.550000
#            islanding                                0.575000
# NC         intentional attack                      17.729167
#            severe weather                          28.982222
#            system operability disruption            1.370000
# ND         fuel supply emergency                         NaN
#            public appeal                           12.000000
# NE         public appeal                            2.650000
#            severe weather                          53.688889
# NH         intentional attack                       1.000000
#            severe weather                          26.625000
# NJ         intentional attack                       1.518750
#            severe weather                         106.214394
#            system operability disruption           12.475000
# NM         fuel supply emergency                    1.266667
#            intentional attack                       2.908333
#            system operability disruption            0.000000
# NV         intentional attack                       9.221429
# NY         equipment failure                        4.116667
#            fuel supply emergency                  278.120833
#            intentional attack                       5.151389
#            public appeal                           44.250000
#            severe weather                         100.576263
#            system operability disruption           19.609524
# OH         equipment failure                             NaN
#            intentional attack                       5.454762
#            severe weather                          72.037821
#            system operability disruption           29.075000
# OK         intentional attack                       1.261111
#            islanding                               16.400000
#            public appeal                           11.733333
#            severe weather                          70.107778
# OR         equipment failure                        3.333333
#            intentional attack                       6.568421
#            severe weather                          38.263333
# PA         equipment failure                        6.266667
#            intentional attack                      25.447222
#            severe weather                          71.900000
#            system operability disruption            5.483333
# SC         severe weather                          52.250000
# SD         islanding                                2.000000
# TN         equipment failure                        6.733333
#            intentional attack                       2.850000
#            public appeal                           45.000000
#            severe weather                          23.105833
#            system operability disruption            0.333333
# TX         equipment failure                        6.760000
#            fuel supply emergency                  232.000000
#            intentional attack                       4.979487
#            public appeal                           19.006863
#            severe weather                          64.248177
#            system operability disruption           13.513333
# UT         equipment failure                        0.250000
#            intentional attack                       2.371429
#            public appeal                           37.916667
#            severe weather                          15.950000
#            system operability disruption            8.958333
# VA         equipment failure                             NaN
#            intentional attack                       0.033333
#            public appeal                           11.391667
#            severe weather                          18.871354
#            system operability disruption            4.016667
# VT         intentional attack                       0.590741
# WA         equipment failure                       20.066667
#            fuel supply emergency                    0.016667
#            intentional attack                       6.197849
#            islanding                                1.222222
#            public appeal                            4.133333
#            severe weather                          91.225833
#            system operability disruption            0.416667
# WI         fuel supply emergency                  566.187500
#            intentional attack                       7.650000
#            public appeal                            6.466667
#            severe weather                          25.457143
# WV         intentional attack                       0.016667
#            severe weather                         155.083333
# WY         equipment failure                        1.016667
#            intentional attack                       0.005556
#            islanding                                0.533333
#            severe weather                           1.766667
#
#                                           Avg # of customers affected
# STATE.ABBR CAUSE.CATEGORY
# AK         equipment failure                             1.427300e+04
# AL         intentional attack                                     NaN
#            severe weather                                9.432880e+04
# AR         equipment failure                                      NaN
#            intentional attack                            9.200000e+03
#            islanding                                              NaN
#            public appeal                                 1.081880e+04
#            severe weather                                7.949514e+04
# AZ         equipment failure                             5.566667e+04
#            intentional attack                            1.356500e+03
#            severe weather                                9.045550e+04
#            system operability disruption                 1.145000e+05
# CA         equipment failure                             1.986081e+05
#            fuel supply emergency                         0.000000e+00
#            intentional attack                            1.066000e+04
#            islanding                                     5.039192e+03
#            public appeal                                          NaN
#            severe weather                                3.610414e+05
#            system operability disruption                 1.520405e+05
# CO         fuel supply emergency                         0.000000e+00
#            intentional attack                            0.000000e+00
#            islanding                                     3.523000e+04
#            severe weather                                8.876450e+04
#            system operability disruption                 3.068950e+04
# CT         intentional attack                            0.000000e+00
#            severe weather                                7.844100e+04
# DC         equipment failure                             5.200000e+04
#            severe weather                                2.125479e+05
# DE         equipment failure                             1.840000e+04
#            intentional attack                            0.000000e+00
#            severe weather                                6.500000e+04
#            system operability disruption                          NaN
# FL         equipment failure                             1.725252e+05
#            intentional attack                            0.000000e+00
#            public appeal                                 0.000000e+00
#            severe weather                                4.449068e+05
#            system operability disruption                 5.272900e+04
# GA         intentional attack                                     NaN
#            severe weather                                1.206802e+05
# HI         severe weather                                1.767215e+05
#            system operability disruption                 2.930000e+04
# IA         intentional attack                            0.000000e+00
#            severe weather                                1.253333e+05
# ID         intentional attack                            0.000000e+00
#            public appeal                                 0.000000e+00
#            system operability disruption                 3.500000e+04
# IL         equipment failure                             5.150000e+04
#            fuel supply emergency                                  NaN
#            intentional attack                            0.000000e+00
#            public appeal                                          NaN
#            severe weather                                2.156594e+05
# IN         equipment failure                             1.240000e+05
#            fuel supply emergency                                  NaN
#            intentional attack                            0.000000e+00
#            islanding                                     9.666667e+03
#            severe weather                                9.456735e+04
#            system operability disruption                 9.175000e+03
# KS         intentional attack                            0.000000e+00
#            public appeal                                          NaN
#            severe weather                                1.512000e+05
# KY         equipment failure                                      NaN
#            fuel supply emergency                         0.000000e+00
#            intentional attack                            1.100000e+02
#            severe weather                                1.631500e+05
# LA         equipment failure                             1.640000e+04
#            fuel supply emergency                                  NaN
#            public appeal                                          NaN
#            severe weather                                2.045186e+05
#            system operability disruption                 3.100025e+04
# MA         fuel supply emergency                         1.000000e+00
#            intentional attack                            1.010000e+04
#            severe weather                                1.371429e+05
#            system operability disruption                 7.962500e+04
# MD         intentional attack                            1.333333e-01
#            severe weather                                1.808022e+05
#            system operability disruption                          NaN
# ME         fuel supply emergency                         0.000000e+00
#            intentional attack                            0.000000e+00
#            islanding                                     0.000000e+00
#            severe weather                                9.322690e+04
# MI         equipment failure                                      NaN
#            intentional attack                            0.000000e+00
#            islanding                                     0.000000e+00
#            public appeal                                          NaN
#            severe weather                                1.383112e+05
#            system operability disruption                 7.597377e+05
# MN         intentional attack                            1.980333e+03
#            severe weather                                1.572865e+05
# MO         intentional attack                            0.000000e+00
#            severe weather                                6.579440e+04
#            system operability disruption                          NaN
# MS         intentional attack                            0.000000e+00
#            system operability disruption                 1.000000e+04
# MT         intentional attack                                     NaN
#            islanding                                              NaN
# NC         intentional attack                            0.000000e+00
#            severe weather                                1.216456e+05
#            system operability disruption                 1.175440e+04
# ND         fuel supply emergency                                  NaN
#            public appeal                                 3.450000e+04
# NE         public appeal                                          NaN
#            severe weather                                8.707067e+04
# NH         intentional attack                            0.000000e+00
#            severe weather                                7.628400e+04
# NJ         intentional attack                            0.000000e+00
#            severe weather                                2.115297e+05
#            system operability disruption                 1.565335e+05
# NM         fuel supply emergency                                  NaN
#            intentional attack                            0.000000e+00
#            system operability disruption                 5.000000e+05
# NV         intentional attack                            2.222000e+04
# NY         equipment failure                             0.000000e+00
#            fuel supply emergency                                  NaN
#            intentional attack                            0.000000e+00
#            public appeal                                 1.860000e+04
#            severe weather                                1.650506e+05
#            system operability disruption                 1.080998e+06
# OH         equipment failure                                      NaN
#            intentional attack                            2.000000e+02
#            severe weather                                1.540072e+05
#            system operability disruption                 6.130000e+05
# OK         intentional attack                            0.000000e+00
#            islanding                                     1.450000e+04
#            public appeal                                          NaN
#            severe weather                                1.899051e+05
# OR         equipment failure                             3.000000e+00
#            intentional attack                            4.166667e+02
#            severe weather                                1.050000e+05
# PA         equipment failure                             4.390300e+04
#            intentional attack                            8.750000e+03
#            severe weather                                1.851408e+05
#            system operability disruption                          NaN
# SC         severe weather                                2.519131e+05
# SD         islanding                                              NaN
# TN         equipment failure                                      NaN
#            intentional attack                            7.166667e+01
#            public appeal                                          NaN
#            severe weather                                7.201286e+04
#            system operability disruption                          NaN
# TX         equipment failure                             8.588250e+04
#            fuel supply emergency                                  NaN
#            intentional attack                            5.523333e+02
#            public appeal                                 0.000000e+00
#            severe weather                                2.580940e+05
#            system operability disruption                 2.896964e+05
# UT         equipment failure                                      NaN
#            intentional attack                            3.052632e+02
#            public appeal                                          NaN
#            severe weather                                6.000000e+04
#            system operability disruption                 7.960500e+04
# VA         equipment failure                             3.700000e+04
#            intentional attack                                     NaN
#            public appeal                                          NaN
#            severe weather                                1.388621e+05
#            system operability disruption                 6.000000e+05
# VT         intentional attack                            0.000000e+00
# WA         equipment failure                             9.330000e+04
#            fuel supply emergency                                  NaN
#            intentional attack                            0.000000e+00
#            islanding                                     0.000000e+00
#            public appeal                                 8.000000e+03
#            severe weather                                1.826765e+05
#            system operability disruption                          NaN
# WI         fuel supply emergency                                  NaN
#            intentional attack                            0.000000e+00
#            public appeal                                 7.600000e+03
#            severe weather                                6.445143e+04
# WV         intentional attack                                     NaN
#            severe weather                                1.797943e+05
# WY         equipment failure                                      NaN
#            intentional attack                            0.000000e+00
#            islanding                                              NaN
#            severe weather                                3.550000e+04

# %%
# sanity check

df[df['STATE.ABBR'] == 'AK']
# Out:
#       YEAR  MONTH U.S._STATE STATE.ABBR NERC.REGION CLIMATE.REGION  \
# 1533  2000    NaN     Alaska         AK        ASCC            NaN
#
#       ANOMALY.LEVEL CLIMATE.CATEGORY     CAUSE.CATEGORY CAUSE.CATEGORY.DETAIL  \
# 1533            NaN              NaN  equipment failure               failure
#
#      HURRICANE.NAMES  OUTAGE.DURATION  DEMAND.LOSS.MW  CUSTOMERS.AFFECTED  \
# 1533             NaN              NaN            35.0             14273.0
#
#       RES.PRICE  COM.PRICE  IND.PRICE  TOTAL.PRICE  RES.SALES  COM.SALES  \
# 1533        NaN        NaN        NaN          NaN        NaN        NaN
#
#       IND.SALES  TOTAL.SALES  RES.PERCEN  COM.PERCEN  IND.PERCEN  \
# 1533        NaN          NaN         NaN         NaN         NaN
#
#       RES.CUSTOMERS  COM.CUSTOMERS  IND.CUSTOMERS  TOTAL.CUSTOMERS  \
# 1533         230534          38074            854           273530
#
#       RES.CUST.PCT  COM.CUST.PCT  IND.CUST.PCT  PC.REALGSP.STATE  \
# 1533       84.2811       13.9195        0.3122             57401
#
#       PC.REALGSP.USA  PC.REALGSP.REL  PC.REALGSP.CHANGE  UTIL.REALGSP  \
# 1533           44745        1.282847               -2.2           724
#
#       TOTAL.REALGSP  UTIL.CONTRI  PI.UTIL.OFUSA  POPULATION  POPPCT_URBAN  \
# 1533          36046     2.008545            0.2      627963         66.02
#
#       POPPCT_UC  POPDEN_URBAN  POPDEN_UC  POPDEN_RURAL  AREAPCT_URBAN  \
# 1533      21.56        1802.6     1276.0           0.4           0.05
#
#       AREAPCT_UC   PCT_LAND  PCT_WATER_TOT  PCT_WATER_INLAND OUTAGE.START  \
# 1533        0.02  85.761154      14.238846          2.901182          NaT
#
#      OUTAGE.END  DURATION.HR
# 1533        NaT          NaN

# %%
group1.head()
# Out:
# CAUSE.CATEGORY  equipment failure  fuel supply emergency  intentional attack  \
# U.S._STATE
# Vermont                       NaN                    NaN            0.590741
# South Dakota                  NaN                    NaN                 NaN
# Montana                       NaN                    NaN            1.550000
# Wyoming                  1.016667                    NaN            0.005556
# New Mexico                    NaN               1.266667            2.908333
#
# CAUSE.CATEGORY  islanding  public appeal  severe weather  \
# U.S._STATE
# Vermont               NaN            NaN             NaN
# South Dakota     2.000000            NaN             NaN
# Montana          0.575000            NaN             NaN
# Wyoming          0.533333            NaN        1.766667
# New Mexico            NaN            NaN             NaN
#
# CAUSE.CATEGORY  system operability disruption
# U.S._STATE
# Vermont                                   NaN
# South Dakota                              NaN
# Montana                                   NaN
# Wyoming                                   NaN
# New Mexico                                0.0

# %%
# Get pivot table of average anomaly level by cause category and category detail

group2 = pd.pivot_table(df, index=['CAUSE.CATEGORY'], \
    columns=['CAUSE.CATEGORY.DETAIL'], values='ANOMALY.LEVEL', aggfunc=np.mean)
fig7 = group2.plot(kind='barh', \
    title='Average anomaly level by cause category, subset by category '+
    'detail<br><sup>Anomaly level represents the oceanic El Niño/La Niña (ONI)'+
    ' index, estimated as a 3-month running mean of ERSST.v4 SST anomalies in'+
    ' the Niño 3.4 region</sup>',
    labels={'CAUSE.CATEGORY': 'cause category', 'value': 'average anomaly level (ONI Index)'})
fig7.update_layout(legend=dict(title='cause category detail'))
fig7

# %%
# Write to html file

path = os.path.join('assets', 'multi_2.html')
fig7.write_html(path, include_plotlyjs='cdn')

# %%
df.head()
# Out:
#    YEAR  MONTH U.S._STATE STATE.ABBR NERC.REGION      CLIMATE.REGION  \
# 0  2011    7.0  Minnesota         MN         MRO  East North Central
# 1  2014    5.0  Minnesota         MN         MRO  East North Central
# 2  2010   10.0  Minnesota         MN         MRO  East North Central
# 3  2012    6.0  Minnesota         MN         MRO  East North Central
# 4  2015    7.0  Minnesota         MN         MRO  East North Central
#
#    ANOMALY.LEVEL CLIMATE.CATEGORY      CAUSE.CATEGORY CAUSE.CATEGORY.DETAIL  \
# 0           -0.3           normal      severe weather                   NaN
# 1           -0.1           normal  intentional attack             vandalism
# 2           -1.5             cold      severe weather            heavy wind
# 3           -0.1           normal      severe weather          thunderstorm
# 4            1.2             warm      severe weather                   NaN
#
#   HURRICANE.NAMES  OUTAGE.DURATION  DEMAND.LOSS.MW  CUSTOMERS.AFFECTED  \
# 0             NaN           3060.0             NaN             70000.0
# 1             NaN              1.0             NaN                 NaN
# 2             NaN           3000.0             NaN             70000.0
# 3             NaN           2550.0             NaN             68200.0
# 4             NaN           1740.0           250.0            250000.0
#
#    RES.PRICE  COM.PRICE  IND.PRICE  TOTAL.PRICE  RES.SALES  COM.SALES  \
# 0      11.60       9.18       6.81         9.28  2332915.0  2114774.0
# 1      12.12       9.71       6.49         9.28  1586986.0  1807756.0
# 2      10.87       8.19       6.07         8.15  1467293.0  1801683.0
# 3      11.79       9.25       6.71         9.19  1851519.0  1941174.0
# 4      13.07      10.16       7.74        10.43  2028875.0  2161612.0
#
#    IND.SALES  TOTAL.SALES  RES.PERCEN  COM.PERCEN  IND.PERCEN  RES.CUSTOMERS  \
# 0  2113291.0    6562520.0   35.549073   32.225029   32.202431        2308736
# 1  1887927.0    5284231.0   30.032487   34.210389   35.727564        2345860
# 2  1951295.0    5222116.0   28.097672   34.501015   37.365983        2300291
# 3  1993026.0    5787064.0   31.994099   33.543330   34.439329        2317336
# 4  1777937.0    5970339.0   33.982576   36.205850   29.779498        2374674
#
#    COM.CUSTOMERS  IND.CUSTOMERS  TOTAL.CUSTOMERS  RES.CUST.PCT  COM.CUST.PCT  \
# 0         276286          10673          2595696       88.9448       10.6440
# 1         284978           9898          2640737       88.8335       10.7916
# 2         276463          10150          2586905       88.9206       10.6870
# 3         278466          11010          2606813       88.8954       10.6822
# 4         289044           9812          2673531       88.8216       10.8113
#
#    IND.CUST.PCT  PC.REALGSP.STATE  PC.REALGSP.USA  PC.REALGSP.REL  \
# 0        0.4112             51268           47586        1.077376
# 1        0.3748             53499           49091        1.089792
# 2        0.3924             50447           47287        1.066826
# 3        0.4224             51598           48156        1.071476
# 4        0.3670             54431           49844        1.092027
#
#    PC.REALGSP.CHANGE  UTIL.REALGSP  TOTAL.REALGSP  UTIL.CONTRI  PI.UTIL.OFUSA  \
# 0                1.6          4802         274182     1.751391            2.2
# 1                1.9          5226         291955     1.790002            2.2
# 2                2.7          4571         267895     1.706266            2.1
# 3                0.6          5364         277627     1.932089            2.2
# 4                1.7          4873         292023     1.668704            2.2
#
#    POPULATION  POPPCT_URBAN  POPPCT_UC  POPDEN_URBAN  POPDEN_UC  POPDEN_RURAL  \
# 0     5348119         73.27      15.28        2279.0     1700.5          18.2
# 1     5457125         73.27      15.28        2279.0     1700.5          18.2
# 2     5310903         73.27      15.28        2279.0     1700.5          18.2
# 3     5380443         73.27      15.28        2279.0     1700.5          18.2
# 4     5489594         73.27      15.28        2279.0     1700.5          18.2
#
#    AREAPCT_URBAN  AREAPCT_UC   PCT_LAND  PCT_WATER_TOT  PCT_WATER_INLAND  \
# 0           2.14         0.6  91.592666       8.407334          5.478743
# 1           2.14         0.6  91.592666       8.407334          5.478743
# 2           2.14         0.6  91.592666       8.407334          5.478743
# 3           2.14         0.6  91.592666       8.407334          5.478743
# 4           2.14         0.6  91.592666       8.407334          5.478743
#
#          OUTAGE.START          OUTAGE.END  DURATION.HR
# 0 2011-07-01 17:00:00 2011-07-03 20:00:00    51.000000
# 1 2014-05-11 18:38:00 2014-05-11 18:39:00     0.016667
# 2 2010-10-26 20:00:00 2010-10-28 22:00:00    50.000000
# 3 2012-06-19 04:30:00 2012-06-20 23:00:00    42.500000
# 4 2015-07-18 02:00:00 2015-07-19 07:00:00    29.000000

# %% [markdown]
# ### Assessment of Missingness

# %%
# Inspect the outages where month is missing (likely MAR, explained by year)

df[df['MONTH'].isna()].head(11)
# Out:
#       YEAR  MONTH      U.S._STATE STATE.ABBR NERC.REGION      CLIMATE.REGION  \
# 239   2000    NaN           Texas         TX        FRCC               South
# 339   2000    NaN         Alabama         AL        SERC           Southeast
# 365   2000    NaN        Illinois         IL        SERC             Central
# 766   2000    NaN  North Carolina         NC        SERC           Southeast
# 887   2000    NaN        Delaware         DE         RFC           Northeast
# 1318  2000    NaN        Virginia         VA        SERC           Southeast
# 1506  2002    NaN          Kansas         KS         SPP               South
# 1530  2006    NaN    North Dakota         ND         MRO  West North Central
# 1533  2000    NaN          Alaska         AK        ASCC                 NaN
#
#       ANOMALY.LEVEL CLIMATE.CATEGORY                 CAUSE.CATEGORY  \
# 239             NaN              NaN              equipment failure
# 339             NaN              NaN                 severe weather
# 365             NaN              NaN                 severe weather
# 766             NaN              NaN                 severe weather
# 887             NaN              NaN  system operability disruption
# 1318            NaN              NaN              equipment failure
# 1506            NaN              NaN                 severe weather
# 1530            NaN              NaN          fuel supply emergency
# 1533            NaN              NaN              equipment failure
#
#      CAUSE.CATEGORY.DETAIL HURRICANE.NAMES  OUTAGE.DURATION  DEMAND.LOSS.MW  \
# 239     transformer outage             NaN              NaN            46.0
# 339           thunderstorm             NaN              NaN             NaN
# 365               wildfire             NaN              NaN             NaN
# 766           thunderstorm             NaN              NaN           175.0
# 887                    NaN             NaN              NaN             NaN
# 1318  relaying malfunction             NaN              NaN           143.0
# 1506          winter storm             NaN              NaN           550.0
# 1530                  Coal             NaN              NaN          1650.0
# 1533               failure             NaN              NaN            35.0
#
#       CUSTOMERS.AFFECTED  RES.PRICE  COM.PRICE  IND.PRICE  TOTAL.PRICE  \
# 239              43000.0        NaN        NaN        NaN          NaN
# 339             160000.0        NaN        NaN        NaN          NaN
# 365              11000.0        NaN        NaN        NaN          NaN
# 766              50000.0        NaN        NaN        NaN          NaN
# 887                  NaN        NaN        NaN        NaN          NaN
# 1318             37000.0        NaN        NaN        NaN          NaN
# 1506            270000.0        NaN        NaN        NaN          NaN
# 1530                 NaN        NaN        NaN        NaN          NaN
# 1533             14273.0        NaN        NaN        NaN          NaN
#
#       RES.SALES  COM.SALES  IND.SALES  TOTAL.SALES  RES.PERCEN  COM.PERCEN  \
# 239         NaN        NaN        NaN          NaN         NaN         NaN
# 339         NaN        NaN        NaN          NaN         NaN         NaN
# 365         NaN        NaN        NaN          NaN         NaN         NaN
# 766         NaN        NaN        NaN          NaN         NaN         NaN
# 887         NaN        NaN        NaN          NaN         NaN         NaN
# 1318        NaN        NaN        NaN          NaN         NaN         NaN
# 1506        NaN        NaN        NaN          NaN         NaN         NaN
# 1530        NaN        NaN        NaN          NaN         NaN         NaN
# 1533        NaN        NaN        NaN          NaN         NaN         NaN
#
#       IND.PERCEN  RES.CUSTOMERS  COM.CUSTOMERS  IND.CUSTOMERS  \
# 239          NaN        8023266        1093414          61280
# 339          NaN        1930037         313017           6252
# 365          NaN        4748863         493670           5009
# 766          NaN        3561203         513727          12577
# 887          NaN         335282          40616            553
# 1318         NaN        2767245         306821           5371
# 1506         NaN        1157820         194996          12885
# 1530         NaN         309997          53709           2331
# 1533         NaN         230534          38074            854
#
#       TOTAL.CUSTOMERS  RES.CUST.PCT  COM.CUST.PCT  IND.CUST.PCT  \
# 239           9299829       86.2733       11.7574        0.6589
# 339           2262753       85.2960       13.8335        0.2763
# 365           5282401       89.8997        9.3456        0.0948
# 766           4105711       86.7378       12.5125        0.3063
# 887            377219       88.8826       10.7672        0.1466
# 1318          3122909       88.6111        9.8248        0.1720
# 1506          1379347       83.9397       14.1368        0.9341
# 1530           366037       84.6901       14.6731        0.6368
# 1533           273530       84.2811       13.9195        0.3122
#
#       PC.REALGSP.STATE  PC.REALGSP.USA  PC.REALGSP.REL  PC.REALGSP.CHANGE  \
# 239              45102           44745        1.007979                1.7
# 339              33712           44745        0.753425                1.1
# 365              49276           44745        1.101263                2.8
# 766              42201           44745        0.943144                1.5
# 887              64013           44745        1.430618                2.1
# 1318             47456           44745        1.060588                2.5
# 1506             40525           45097        0.898619                1.1
# 1530             42913           48909        0.877405                3.5
# 1533             57401           44745        1.282847               -2.2
#
#       UTIL.REALGSP  TOTAL.REALGSP  UTIL.CONTRI  PI.UTIL.OFUSA  POPULATION  \
# 239          30908         944631     3.271965           10.3    20944499
# 339           5704         150090     3.800386            2.2     4452173
# 365          15815         612709     2.581160            5.8    12434161
# 766           8262         341051     2.422512            2.2     8081614
# 887           1016          50338     2.018356            0.4      786373
# 1318          6978         337211     2.069328            1.8     7105817
# 1506          2462         109966     2.238874            1.1     2713535
# 1530          1019          27868     3.656524            0.7      649422
# 1533           724          36046     2.008545            0.2      627963
#
#       POPPCT_URBAN  POPPCT_UC  POPDEN_URBAN  POPDEN_UC  POPDEN_RURAL  \
# 239          84.70       9.35        2435.3     1539.9          15.2
# 339          59.04      10.39        1278.5      988.7          40.4
# 365          88.49       8.52        2877.6     1759.5          28.6
# 766          66.09      11.21        1367.2     1043.7          73.5
# 887          83.30      14.59        1838.3     1083.0          97.3
# 1318         75.45       5.66        2265.2     1179.2          53.3
# 1506         74.20      24.03        2176.5     1983.0           9.1
# 1530         59.90      19.90        2192.2     1868.2           3.9
# 1533         66.02      21.56        1802.6     1276.0           0.4
#
#       AREAPCT_URBAN  AREAPCT_UC   PCT_LAND  PCT_WATER_TOT  PCT_WATER_INLAND  \
# 239            3.35        0.58  97.258336       2.742036          2.090873
# 339            4.36        0.99  96.613888       3.386112          2.018314
# 365            7.11        1.12  95.864558       4.135442          1.415893
# 766            9.48        2.11  90.336127       9.663873          7.528940
# 887           20.88        6.21  78.304540      21.695460          3.656087
# 1318           6.75        0.97  92.320281       7.679719          2.997078
# 1506           1.19        0.42  99.369212       0.632004          0.632004
# 1530           0.27        0.10  97.599649       2.401765          2.401765
# 1533           0.05        0.02  85.761154      14.238846          2.901182
#
#      OUTAGE.START OUTAGE.END  DURATION.HR
# 239           NaT        NaT          NaN
# 339           NaT        NaT          NaN
# 365           NaT        NaT          NaN
# 766           NaT        NaT          NaN
# 887           NaT        NaT          NaN
# 1318          NaT        NaT          NaN
# 1506          NaT        NaT          NaN
# 1530          NaT        NaT          NaN
# 1533          NaT        NaT          NaN

# %%
# Inspect the outages where demand loss is missing (demand loss is likely NMAR)

df[df['DEMAND.LOSS.MW'].isna()].head(11)
# Out:
#     YEAR  MONTH U.S._STATE STATE.ABBR NERC.REGION      CLIMATE.REGION  \
# 0   2011    7.0  Minnesota         MN         MRO  East North Central
# 1   2014    5.0  Minnesota         MN         MRO  East North Central
# 2   2010   10.0  Minnesota         MN         MRO  East North Central
# 3   2012    6.0  Minnesota         MN         MRO  East North Central
# 5   2010   11.0  Minnesota         MN         MRO  East North Central
# 6   2010    7.0  Minnesota         MN         MRO  East North Central
# 9   2013    6.0  Minnesota         MN         MRO  East North Central
# 10  2013    6.0  Minnesota         MN         MRO  East North Central
# 11  2005    9.0  Minnesota         MN         MRO  East North Central
# 14  2014    6.0  Minnesota         MN         MRO  East North Central
# 16  2012    8.0  Tennessee         TN        SERC             Central
#
#     ANOMALY.LEVEL CLIMATE.CATEGORY      CAUSE.CATEGORY CAUSE.CATEGORY.DETAIL  \
# 0            -0.3           normal      severe weather                   NaN
# 1            -0.1           normal  intentional attack             vandalism
# 2            -1.5             cold      severe weather            heavy wind
# 3            -0.1           normal      severe weather          thunderstorm
# 5            -1.4             cold      severe weather          winter storm
# 6            -0.9             cold      severe weather             tornadoes
# 9            -0.2           normal      severe weather             hailstorm
# 10           -0.2           normal      severe weather             hailstorm
# 11            0.0           normal      severe weather             tornadoes
# 14            0.0           normal      severe weather          thunderstorm
# 16            0.3           normal  intentional attack             vandalism
#
#    HURRICANE.NAMES  OUTAGE.DURATION  DEMAND.LOSS.MW  CUSTOMERS.AFFECTED  \
# 0              NaN           3060.0             NaN             70000.0
# 1              NaN              1.0             NaN                 NaN
# 2              NaN           3000.0             NaN             70000.0
# 3              NaN           2550.0             NaN             68200.0
# 5              NaN           1860.0             NaN             60000.0
# 6              NaN           2970.0             NaN             63000.0
# 9              NaN           3621.0             NaN            400000.0
# 10             NaN           7740.0             NaN            193000.0
# 11             NaN           8880.0             NaN            200000.0
# 14             NaN             60.0             NaN             55951.0
# 16             NaN              0.0             NaN                 NaN
#
#     RES.PRICE  COM.PRICE  IND.PRICE  TOTAL.PRICE  RES.SALES  COM.SALES  \
# 0       11.60       9.18       6.81         9.28  2332915.0  2114774.0
# 1       12.12       9.71       6.49         9.28  1586986.0  1807756.0
# 2       10.87       8.19       6.07         8.15  1467293.0  1801683.0
# 3       11.79       9.25       6.71         9.19  1851519.0  1941174.0
# 5       10.63       8.34       6.15         8.28  1676347.0  1786144.0
# 6       11.41       9.11       6.71         9.12  2187537.0  2100828.0
# 9       12.71      10.31       7.29        10.00  1688619.0  1895099.0
# 10      12.71      10.31       7.29        10.00  1688619.0  1895099.0
# 11       8.76       7.58       4.94         7.03  1720089.0  1884242.0
# 14      12.73      10.53       6.97        10.02  1753319.0  1935822.0
# 16      10.00      10.21       7.75         9.47  4401454.0  2833658.0
#
#     IND.SALES  TOTAL.SALES  RES.PERCEN  COM.PERCEN  IND.PERCEN  RES.CUSTOMERS  \
# 0   2113291.0    6562520.0   35.549073   32.225029   32.202431        2308736
# 1   1887927.0    5284231.0   30.032487   34.210389   35.727564        2345860
# 2   1951295.0    5222116.0   28.097672   34.501015   37.365983        2300291
# 3   1993026.0    5787064.0   31.994099   33.543330   34.439329        2317336
# 5   1909874.0    5374150.0   31.192784   33.235842   35.538160        2300291
# 6   2084709.0    6374935.0   34.314656   32.954501   32.701651        2300291
# 9   1905375.0    5490631.0   30.754553   34.515140   34.702296        2329734
# 10  1905375.0    5490631.0   30.754553   34.515140   34.702296        2329734
# 11  1928620.0    5535009.0   31.076535   34.042257   34.844026        2211000
# 14  1883117.0    5574073.0   31.454898   34.729039   33.783501        2345860
# 16  2556236.0    9791474.0   44.951904   28.940055   26.106754        2721099
#
#     COM.CUSTOMERS  IND.CUSTOMERS  TOTAL.CUSTOMERS  RES.CUST.PCT  COM.CUST.PCT  \
# 0          276286          10673          2595696       88.9448       10.6440
# 1          284978           9898          2640737       88.8335       10.7916
# 2          276463          10150          2586905       88.9206       10.6870
# 3          278466          11010          2606813       88.8954       10.6822
# 5          276463          10150          2586905       88.9206       10.6870
# 6          276463          10150          2586905       88.9206       10.6870
# 9          281187          11383          2622305       88.8430       10.7229
# 10         281187          11383          2622305       88.8430       10.7229
# 11         255645           8266          2474912       89.3365       10.3295
# 14         284978           9898          2640737       88.8335       10.7916
# 16         466513           1957          3189570       85.3124       14.6262
#
#     IND.CUST.PCT  PC.REALGSP.STATE  PC.REALGSP.USA  PC.REALGSP.REL  \
# 0         0.4112             51268           47586        1.077376
# 1         0.3748             53499           49091        1.089792
# 2         0.3924             50447           47287        1.066826
# 3         0.4224             51598           48156        1.071476
# 5         0.3924             50447           47287        1.066826
# 6         0.3924             50447           47287        1.066826
# 9         0.4341             52479           48396        1.084366
# 10        0.4341             52479           48396        1.084366
# 11        0.3340             52445           48090        1.090559
# 14        0.3748             53499           49091        1.089792
# 16        0.0614             41469           48156        0.861139
#
#     PC.REALGSP.CHANGE  UTIL.REALGSP  TOTAL.REALGSP  UTIL.CONTRI  \
# 0                 1.6          4802         274182     1.751391
# 1                 1.9          5226         291955     1.790002
# 2                 2.7          4571         267895     1.706266
# 3                 0.6          5364         277627     1.932089
# 5                 2.7          4571         267895     1.706266
# 6                 2.7          4571         267895     1.706266
# 9                 1.7          5613         284542     1.972644
# 10                1.7          5613         284542     1.972644
# 11                2.0          3997         268496     1.488663
# 14                1.9          5226         291955     1.790002
# 16                2.5          1819         267689     0.679520
#
#     PI.UTIL.OFUSA  POPULATION  POPPCT_URBAN  POPPCT_UC  POPDEN_URBAN  \
# 0             2.2     5348119         73.27      15.28        2279.0
# 1             2.2     5457125         73.27      15.28        2279.0
# 2             2.1     5310903         73.27      15.28        2279.0
# 3             2.2     5380443         73.27      15.28        2279.0
# 5             2.1     5310903         73.27      15.28        2279.0
# 6             2.1     5310903         73.27      15.28        2279.0
# 9             2.3     5420541         73.27      15.28        2279.0
# 10            2.3     5420541         73.27      15.28        2279.0
# 11            2.1     5119598         73.27      15.28        2279.0
# 14            2.2     5457125         73.27      15.28        2279.0
# 16            0.4     6455469         66.39      12.02        1450.3
#
#     POPDEN_UC  POPDEN_RURAL  AREAPCT_URBAN  AREAPCT_UC   PCT_LAND  \
# 0      1700.5          18.2           2.14        0.60  91.592666
# 1      1700.5          18.2           2.14        0.60  91.592666
# 2      1700.5          18.2           2.14        0.60  91.592666
# 3      1700.5          18.2           2.14        0.60  91.592666
# 5      1700.5          18.2           2.14        0.60  91.592666
# 6      1700.5          18.2           2.14        0.60  91.592666
# 9      1700.5          18.2           2.14        0.60  91.592666
# 10     1700.5          18.2           2.14        0.60  91.592666
# 11     1700.5          18.2           2.14        0.60  91.592666
# 14     1700.5          18.2           2.14        0.60  91.592666
# 16     1076.2          55.6           7.05        1.72  97.843109
#
#     PCT_WATER_TOT  PCT_WATER_INLAND        OUTAGE.START          OUTAGE.END  \
# 0        8.407334          5.478743 2011-07-01 17:00:00 2011-07-03 20:00:00
# 1        8.407334          5.478743 2014-05-11 18:38:00 2014-05-11 18:39:00
# 2        8.407334          5.478743 2010-10-26 20:00:00 2010-10-28 22:00:00
# 3        8.407334          5.478743 2012-06-19 04:30:00 2012-06-20 23:00:00
# 5        8.407334          5.478743 2010-11-13 15:00:00 2010-11-14 22:00:00
# 6        8.407334          5.478743 2010-07-17 20:30:00 2010-07-19 22:00:00
# 9        8.407334          5.478743 2013-06-21 17:39:00 2013-06-24 06:00:00
# 10       8.407334          5.478743 2013-06-21 03:00:00 2013-06-26 12:00:00
# 11       8.407334          5.478743 2005-09-21 19:00:00 2005-09-27 23:00:00
# 14       8.407334          5.478743 2014-06-15 00:00:00 2014-06-15 01:00:00
# 16       2.156891          2.156891 2012-08-13 13:15:00 2012-08-13 13:15:00
#
#     DURATION.HR
# 0     51.000000
# 1      0.016667
# 2     50.000000
# 3     42.500000
# 5     31.000000
# 6     49.500000
# 9     60.350000
# 10   129.000000
# 11   148.000000
# 14     1.000000
# 16     0.000000

# %% [markdown]
# ### Hypothesis Testing

# %%
# TODO
